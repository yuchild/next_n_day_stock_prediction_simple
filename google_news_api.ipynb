# %%
import http.client

conn = http.client.HTTPSConnection("google-news.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "google-news.p.rapidapi.com",
    'x-rapidapi-key': "d8bd99579amsh60d48190a20b6d4p18dcbdjsnd5edf570cb37"
    }

conn.request("GET", "/v1/source_search?source=nytimes.com&lang=en&country=US", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"feed":{"title":"\"allinurl:nytimes.com\" - Google News","updated":"Wed, 01 Sep 2021 18:00:44 GMT","link":"https://news.google.com/search?q=allinurl:nytimes.com&ceid=US:en&hl=en-US&gl=US","language":"en-US","subtitle":"Google News","rights":"2021 Google Inc."},"articles":[{"id":"CAIiEHAdlXYu8gZs_v6H4cF1lcoqFwgEKg8IACoHCAowjuuKAzCWrzww9oAY","title":"Allbirds's I.P.O. Filing Shows Losses but Grand Ambitions - The New York Times","link":"https://www.nytimes.com/2021/08/31/business/allbirds-ipo.html","published":"Tue, 31 Aug 2021 16:38:45 GMT","sub_articles":[],"source":{"href":"https://www.nytimes.com","title":"The New York Times"}},{"id":"CAIiEL89VxOnRPMlW_6kXWfkSHEqFwgEKg8IACoHCAowjuuKAzCWrzww9oAY","title":"Stocks Shake Off Bad News to Rally for Seventh Straight Month - The New York Times","link":"https://www.nytimes.com/2021/08/31/business/stock-market-record.html","published":"Tue, 31 Aug 2021 21:08:19 GMT","sub_articles":[],"source":{"href":"https://www.nytimes.com","title":"The N
# ...
